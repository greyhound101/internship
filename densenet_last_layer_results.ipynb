# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/densenet_last_layer_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile
with ZipFile('densenet_fold_1_last.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# answers_all_fold_1_densenet_last.npy           2020-05-28 18:31:28          921
# final_accuracy_all_fold1_densenet_last.npy     2020-05-28 18:31:28          397
# history_all_fold_1_densenet_last.npy           2020-05-28 18:31:28         7737
# times_all_fold_1_densenet_last.npy             2020-05-28 18:31:28          305
# predictions_all_fold_1_densenet_last.npy       2020-05-28 18:31:28         4721
# predictions_all_best_fold_1_densenet_last.npy  2020-05-28 18:31:28         4721
# best_accuracy_all_fold_1_densenet_last.npy     2020-05-28 18:31:28          397
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_last_fold3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_last_fold5.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_densenet_last.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.5116743040347168

# %%
import numpy as np
fnl_acc3=list(np.load('best_accuracy_last_fold3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('best_accuracy_last_fold5.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('best_accuracy_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('best_accuracy_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('best_accuracy_all_fold_1_densenet_last.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.5873094568705262

# %%
import numpy as np
fnl_acc3=list(np.load('times_last_fold3_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_last_fold5.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_densenet_last.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 15825.99797515869

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_densenet_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_densenet_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[111   1   0]
#  [ 95 150   0]
#  [150  35   0]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_densenet_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_1_densenet_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 92  20   0]
#  [ 31 214   0]
#  [103  78   4]]

# %%
ans_1=np.load('answers_last_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[155  12   0]
#  [138 200   0]
#  [149  25   0]]

# %%
ans_1=np.load('answers_last_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[112  55   0]
#  [ 55 283   0]
#  [112  62   0]]

# %%
ans_1=np.load('answers_last_fold3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 91  48   0]
#  [ 36 195   0]
#  [ 25 177   0]]

# %%
ans_1=np.load('answers_last_fold3_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold3_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[129  10   0]
#  [ 63 168   0]
#  [ 87 115   0]]

# %%
ans_1=np.load('answers_last_fold4.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold4.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 45  79   0]
#  [  5 320   0]
#  [ 11 168   0]]

# %%
ans_1=np.load('answers_last_fold4.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold4.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 27  84  13]
#  [  3 315   7]
#  [ 30  51  98]]

# %%
ans_1=np.load('answers_last_fold5.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold5.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[155  11   0]
#  [138 149   0]
#  [131  59   0]]

# %%
ans_1=np.load('answers_last_fold5.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold5.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[131  35   0]
#  [ 56 231   0]
#  [ 74 116   0]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_densenet_last.npy',allow_pickle=True).item()
history['fold2']=np.load('history_last_fold2_wn.npy',allow_pickle=True).item()
history['fold3']=np.load('history_last_fold3_wn.npy',allow_pickle=True).item()
history['fold4']=np.load('history_last_fold4.npy',allow_pickle=True).item()
history['fold5']=np.load('history_last_fold5.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_accuracy')
    plt.title('Training all layers')
    plt.show()
