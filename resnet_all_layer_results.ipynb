# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/resnet_all_layer_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile 
  
with ZipFile('resnet_all_!.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# history_all_fold_1_Resnet_all.npy              2020-05-27 18:32:34         7737
# predictions_all_fold_1_Resnet_all.npy          2020-05-27 18:32:34         4721
# times_all_fold_1_Resnet_all.npy                2020-05-27 18:32:34          305
# final_accuracy_all_fold1_Resnet_all.npy        2020-05-27 18:32:34          397
# best_accuracy_all_fold_1_Resnet_all.npy        2020-05-27 18:32:34          397
# answers_all_fold_1_Resnet_all.npy              2020-05-27 18:32:34         4721
# predictions_all_best_fold_1_Resnet_all.npy     2020-05-27 18:32:34         4721
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile 
  
with ZipFile('resnet_fold_5_all.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# predictions_all_fold_5_Resnet_all.npy          2020-05-27 15:27:54         5529
# final_accuracy_all_fold5_Resnet_all.npy        2020-05-27 15:27:54          397
# answers_all_fold_5_Resnet_all.npy              2020-05-27 15:27:54         5529
# times_all_fold_5_Resnet_all.npy                2020-05-27 15:27:54          305
# predictions_all_best_fold_5_Resnet_all.npy     2020-05-27 15:27:54         5529
# best_accuracy_all_fold_5_Resnet_all.npy        2020-05-27 15:27:54          397
# history_all_fold_5_Resnet_all.npy              2020-05-27 15:27:54         3640
# Extracting all the files now...
# Done!

# %%
fnl_acc1
# Out:
# 0.3413284132841328

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_Resnet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_last_fold2.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_Resnet_all.npy',allow_pickle=True).item().values())[0]
print([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# [0.3413284132841328, 0.9293078055964654, 0.9475524475524476, 0.9745222929936306, 0.9300155520995335]

# %%
import numpy as np
fnl_acc3=list(np.load('best_accuracy_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('best_accuracy_all_fold_5_Resnet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('best_accuracy_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('best_accuracy_last_fold2.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('best_accuracy_all_fold_1_Resnet_all.npy',allow_pickle=True).item().values())[0]
print([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# [0.3413284132841328, 0.9440353460972017, 0.9527972027972028, 0.9777070063694268, 0.9331259720062208]

# %%
import numpy as np
fnl_acc3=list(np.load('times_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_Resnet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_last_fold2.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_Resnet_all.npy',allow_pickle=True).item().values())[0]
print([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# [24428.339292764664, 12227.199373960495, 12670.441045284271, 12337.730431556702, 12700.594772577286]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_Resnet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_Resnet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0   0 112]
#  [  0   0 245]
#  [  0   0 185]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_Resnet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_1_Resnet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0   0 112]
#  [  0   0 245]
#  [  0   0 185]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold2.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold2.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[149  15   3]
#  [ 13 321   4]
#  [  3  10 161]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold2.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold2.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[152  13   2]
#  [  6 329   3]
#  [  4  10 160]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_VGG19_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_VGG19_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[120  17   2]
#  [ 13 218   0]
#  [  7   4 191]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold3.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold3.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[134   4   1]
#  [ 21 210   0]
#  [  1   0 201]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold4.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold4.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[113   8   3]
#  [  1 324   0]
#  [  2   2 175]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold4.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold4.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[118   4   2]
#  [  1 323   1]
#  [  3   3 173]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_Resnet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_Resnet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[140   4  22]
#  [ 17 268   2]
#  [  0   0 190]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_Resnet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_5_Resnet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[140   4  22]
#  [ 15 270   2]
#  [  0   0 190]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_Resnet_all.npy',allow_pickle=True).item()
history['fold2']=np.load('history_last_fold2.npy',allow_pickle=True).item()
history['fold3']=np.load('history_last_fold3.npy',allow_pickle=True).item()
history['fold4']=np.load('history_last_fold4.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_Resnet_all.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_accuracy')
    plt.title('Training all layers')
    plt.show()
