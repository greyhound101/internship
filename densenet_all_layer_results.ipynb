# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/densenet_all_layer_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile 
  
with ZipFile('densenet_all_fold_4.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# predictions_all_fold4_wn.npy                   2020-05-26 03:59:22         5409
# answers_all_fold4_wn.npy                       2020-05-26 03:59:22         5409
# times_all_fold4_wn.npy                         2020-05-26 03:59:34          305
# best_accuracy_all_fold4_wn.npy                 2020-05-26 03:59:30          397
# final_accuracy_all_fold4_wn.npy                2020-05-26 03:59:32          397
# history_all_fold4_wn.npy                       2020-05-26 03:59:22         3640
# predictions_all_best_fold4_wn.npy              2020-05-26 03:59:32         5409
# Extracting all the files now...
# Done!

# %%
with ZipFile('densenet_all_fold_2.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# history_all_fold2_wn.npy                       2020-05-26 08:58:26         3640
# answers_all_fold2_wn.npy                       2020-05-26 08:58:26         5817
# predictions_all_fold2_wn.npy                   2020-05-26 08:58:26         5817
# best_accuracy_all_fold2_wn.npy                 2020-05-26 08:58:26          397
# final_accuracy_all_fold2_wn.npy                2020-05-26 08:58:26          397
# times_all_fold2_wn.npy                         2020-05-26 08:58:26          305
# predictions_all_best_fold2_wn.npy              2020-05-26 08:58:26         5817
# Extracting all the files now...
# Done!

# %%
with ZipFile('densenet_all_fold_5.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# times_all_fold5_wn.npy                         2020-05-26 08:28:00          305
# predictions_all_best_fold5_wn.npy              2020-05-26 08:28:00         5529
# final_accuracy_all_fold5_wn.npy                2020-05-26 08:28:00          397
# best_accuracy_all_fold5_wn.npy                 2020-05-26 08:28:00          397
# answers_all_fold5_wn.npy                       2020-05-26 08:28:00         5529
# history_all_fold5_wn.npy                       2020-05-26 08:28:00         3640
# predictions_all_fold5_wn.npy                   2020-05-26 08:28:00         5529
# Extracting all the files now...
# Done!

# %%
with ZipFile('densenet_fold_1_all.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# answers_last_fold1.npy                         2020-05-26 23:50:04         5409
# final_accuracy_all_fold1.npy                   2020-05-26 23:50:04          397
# best_accuracy_all_fold1.npy                    2020-05-26 23:50:04          397
# history_last_fold1.npy                         2020-05-26 23:50:04         3640
# predictions_last_fold1.npy                     2020-05-26 23:50:04         5409
# predictions_all_best_fold1.npy                 2020-05-26 23:50:04         5409
# times_all_fold1.npy                            2020-05-26 23:50:04          305
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1.npy',allow_pickle=True).item().values())
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# array([0.94448918])

# %%
import numpy as np
fnl_acc3=list(np.load('best_accuracy_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('best_accuracy_all_fold5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('best_accuracy_all_fold4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('best_accuracy_all_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('best_accuracy_all_fold1.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9648633152019453

# %%
import numpy as np
fnl_acc3=list(np.load('times_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold1.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 15192.38110947609

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 85  26  13]
#  [  3 317   5]
#  [  2   0 177]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold1.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[104  12   8]
#  [  6 317   2]
#  [  3   0 176]]

# %%
ans_1=np.load('answers_all_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[156  10   1]
#  [  7 329   2]
#  [  0  12 162]]

# %%
ans_1=np.load('answers_all_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[156  10   1]
#  [  4 332   2]
#  [  0   8 166]]

# %%
ans_1=np.load('answers_last_fold3.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold3.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[131   7   1]
#  [ 10 221   0]
#  [  3   1 198]]

# %%
ans_1=np.load('answers_last_fold3.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold3.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[133   6   0]
#  [ 11 220   0]
#  [  2   0 200]]

# %%
ans_1=np.load('answers_all_fold4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[116   6   2]
#  [  1 324   0]
#  [  0   2 177]]

# %%
ans_1=np.load('answers_all_fold4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[118   4   2]
#  [  0 325   0]
#  [  0   2 177]]

# %%
ans_1=np.load('answers_all_fold5_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold5_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[124  18  24]
#  [ 16 271   0]
#  [  2   2 186]]

# %%
ans_1=np.load('answers_all_fold5_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold5_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[144   2  20]
#  [  4 282   1]
#  [  0   1 189]]

# %%
history={}
history['fold1']=np.load('history_last_fold1.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold2_wn.npy',allow_pickle=True).item()
history['fold3']=np.load('history_last_fold3.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold4_wn.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold5_wn.npy',allow_pickle=True).item()

# %%
history['fold1']['fold_1']=history['fold1']['fold_4']

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_accuracy')
    plt.title('Training all layers')
    plt.show()
