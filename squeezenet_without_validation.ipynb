# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/squeezenet_without_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile
with ZipFile('squeezenet_without_validation_fold_1.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# history_all_fold_1_squeezenet_all_without_validation.npy 2020-06-01 12:33:44         2684
# times_all_fold_1_squeezenet_all_without_validation.npy 2020-06-01 12:33:44          305
# final_accuracy_all_fold1_squeezenet_all_without_validation.npy 2020-06-01 12:33:44          397
# predictions_all_fold_1_squeezenet_all_without_validation.npy 2020-06-01 12:33:44         4721
# predictions_all_best_fold_1_squeezenet_all_without_validation.npy 2020-06-01 12:33:44         4721
# best_accuracy_all_fold_1_squeezenet_all_without_validation.npy 2020-06-01 12:33:44          397
# answers_all_fold_1_squeezenet_all_without_validation.npy 2020-06-01 12:33:44         4721
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile
with ZipFile('squeezenet_without_validation_fold_2.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# times_all_fold_2_squeezenet_all_without_validation.npy 2020-06-01 12:39:22          305
# final_accuracy_all_fold2_squeezenet_all_without_validation.npy 2020-06-01 12:39:22          397
# best_accuracy_all_fold_2_squeezenet_all_without_validation.npy 2020-06-01 12:39:22          397
# predictions_all_fold_2_squeezenet_all_without_validation.npy 2020-06-01 12:39:22         5817
# history_all_fold_2_squeezenet_all_without_validation.npy 2020-06-01 12:39:22         2684
# answers_all_fold_2_squeezenet_all_without_validation.npy 2020-06-01 12:39:22         5817
# predictions_all_best_fold_2_squeezenet_all_without_validation.npy 2020-06-01 12:39:22         5817
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile
with ZipFile('squeezenet_without_validation_fold_3.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# best_accuracy_all_fold_3_squeezenet_all_without_validation.npy 2020-06-01 12:47:20          397
# history_all_fold_3_squeezenet_all_without_validation.npy 2020-06-01 12:47:20         2684
# final_accuracy_all_fold3_squeezenet_all_without_validation.npy 2020-06-01 12:47:20          397
# answers_all_fold_3_squeezenet_all_without_validation.npy 2020-06-01 12:47:20         4961
# predictions_all_fold_3_squeezenet_all_without_validation.npy 2020-06-01 12:47:20         4961
# times_all_fold_3_squeezenet_all_without_validation.npy 2020-06-01 12:47:20          305
# predictions_all_best_fold_3_squeezenet_all_without_validation.npy 2020-06-01 12:47:20         4961
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile
with ZipFile('squeezenet_without_validation_fold_4.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# best_accuracy_all_fold_4_squeezenet_all_without_validation.npy 2020-06-01 12:39:28          397
# final_accuracy_all_fold4_squeezenet_all_without_validation.npy 2020-06-01 12:39:28          397
# history_all_fold_4_squeezenet_all_without_validation.npy 2020-06-01 12:39:28         2684
# predictions_all_fold_4_squeezenet_all_without_validation.npy 2020-06-01 12:39:28         5409
# answers_all_fold_4_squeezenet_all_without_validation.npy 2020-06-01 12:39:28         5409
# predictions_all_best_fold_4_squeezenet_all_without_validation.npy 2020-06-01 12:39:28         5409
# times_all_fold_4_squeezenet_all_without_validation.npy 2020-06-01 12:39:28          305
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile
with ZipFile('squeezenet_without_validation_fold_5.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# history_all_fold_5_squeezenet_all_without_validation.npy 2020-06-01 12:52:52         2684
# times_all_fold_5_squeezenet_all_without_validation.npy 2020-06-01 12:52:52          305
# predictions_all_fold_5_squeezenet_all_without_validation.npy 2020-06-01 12:52:52         5529
# answers_all_fold_5_squeezenet_all_without_validation.npy 2020-06-01 12:52:52         5529
# predictions_all_best_fold_5_squeezenet_all_without_validation.npy 2020-06-01 12:52:52         5529
# final_accuracy_all_fold5_squeezenet_all_without_validation.npy 2020-06-01 12:52:52          397
# best_accuracy_all_fold_5_squeezenet_all_without_validation.npy 2020-06-01 12:52:52          397
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9443889884526222

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_squeezenet_all_without_validation.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 5103.36457695961

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_squeezenet_all_without_validation.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_squeezenet_all_without_validation.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[106   5   1]
#  [  4 240   1]
#  [ 14   1 170]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_squeezenet_all_without_validation.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_squeezenet_all_without_validation.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[136  22   9]
#  [  6 321  11]
#  [  1   1 172]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_squeezenet_all_without_validation.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_squeezenet_all_without_validation.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[131   5   3]
#  [ 12 219   0]
#  [  3   0 199]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_squeezenet_all_without_validation.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_squeezenet_all_without_validation.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[102   8  14]
#  [  2 320   3]
#  [  2   2 175]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_squeezenet_all_without_validation.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_squeezenet_all_without_validation.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[138   4  24]
#  [ 11 273   3]
#  [  0   1 189]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_squeezenet_all_without_validation.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_squeezenet_all_without_validation.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_squeezenet_all_without_validation.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_squeezenet_all_without_validation.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_squeezenet_all_without_validation.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
