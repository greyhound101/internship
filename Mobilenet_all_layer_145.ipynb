# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/Mobilenet_all_layer_145.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold1_Mobilenet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold2_Mobilenet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold3_Mobilenet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold4_Mobilenet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold5_MobileNet_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.955670912271682

# %%
fnl_acc3=list(np.load('times_all_fold_3_Mobilenet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_MobileNet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_Mobilenet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_Mobilenet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_Mobilenet_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 7993.276734352112

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_Mobilenet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_Mobilenet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[110   2   0]
#  [  6 239   0]
#  [ 15   0 170]]

# %%
ans_1=np.load('answers_all_fold_2_Mobilenet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_Mobilenet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[158   8   1]
#  [  9 325   4]
#  [  2   0 172]]

# %%
ans_1=np.load('answers_all_fold_3_Mobilenet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_Mobilenet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[136   1   2]
#  [ 19 212   0]
#  [  2   0 200]]

# %%
ans_1=np.load('answers_all_fold_4_Mobilenet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_Mobilenet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[113   8   3]
#  [  6 319   0]
#  [  5   0 174]]

# %%
ans_1=np.load('answers_all_fold_5_MobileNet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_MobileNet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[139   4  23]
#  [ 13 273   1]
#  [  0   2 188]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('mobilenet.png')

# %%
history={}
history['fold1']=np.load('history_all_fold_1_Mobilenet_decay_145.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_Mobilenet_decay_145.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_Mobilenet_decay_145.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_Mobilenet_decay_145.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_MobileNet_decay_145.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
