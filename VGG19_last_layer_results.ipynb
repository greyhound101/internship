# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/VGG19_last_layer_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile 
  
with ZipFile('VGG_19_fold_4.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# history_all_fold_4_VGG19_last.npy              2020-05-27 07:34:20         7737
# best_accuracy_all_fold_4_VGG19_last.npy        2020-05-27 07:34:20          397
# times_all_fold_4_VGG19_last.npy                2020-05-27 07:34:20          305
# final_accuracy_all_fold4_VGG19_last.npy        2020-05-27 07:34:20          397
# predictions_all_fold_4_VGG19_last.npy          2020-05-27 07:34:20         5409
# answers_all_fold_4_VGG19_last.npy              2020-05-27 07:34:20         5409
# predictions_all_best_fold_4_VGG19_last.npy     2020-05-27 07:34:20         5409
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile 
  
with ZipFile('VGG19_3_last.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# predictions_all_fold_3_VGG19_last.npy          2020-05-28 14:14:34         4961
# times_all_fold_3_VGG19_last.npy                2020-05-28 14:14:34          305
# history_all_fold_3_VGG19_last.npy              2020-05-28 14:14:34         7737
# final_accuracy_all_fold3_VGG19_last.npy        2020-05-28 14:14:34          397
# best_accuracy_all_fold_3_VGG19_last.npy        2020-05-28 14:14:34          397
# predictions_all_best_fold_3_VGG19_last.npy     2020-05-28 14:14:34         4961
# answers_all_fold_3_VGG19_last.npy              2020-05-28 14:14:34         4961
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile 
  
with ZipFile('VGG19_5_last.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# times_all_fold_5_VGG19_last.npy                2020-05-28 17:51:02          305
# predictions_all_fold_5_VGG19_last.npy          2020-05-28 17:51:02         5529
# history_all_fold_5_VGG19_last.npy              2020-05-28 17:51:02         7737
# answers_all_fold_5_VGG19_last.npy              2020-05-28 17:51:02         1022
# final_accuracy_all_fold5_VGG19_last.npy        2020-05-28 17:51:02          397
# predictions_all_best_fold_5_VGG19_last.npy     2020-05-28 17:51:02         5529
# best_accuracy_all_fold_5_VGG19_last.npy        2020-05-28 17:51:02          397
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.8442468700797102

# %%
import numpy as np
fnl_acc3=list(np.load('best_accuracy_all_fold_3_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('best_accuracy_all_fold_5_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('best_accuracy_all_fold_4_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('best_accuracy_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('best_accuracy_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc4,fnl_acc5])
# Out:
# 0.8580199616553725

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc4,fnl_acc5])
# Out:
# 11606.032673299313

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 85  26   1]
#  [ 12 231   2]
#  [ 13   6 166]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 86  24   2]
#  [ 14 228   3]
#  [ 10   4 171]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 90  59  18]
#  [ 29 301   8]
#  [  2   7 165]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[127  27  13]
#  [ 54 276   8]
#  [  9   4 161]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_VGG19_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_VGG19_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 85  47   7]
#  [ 28 200   3]
#  [  0   6 196]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_VGG19_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_3_VGG19_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[111  23   5]
#  [ 40 187   4]
#  [  1   6 195]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_VGG19_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_VGG19_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 92  25   7]
#  [ 31 289   5]
#  [  6   1 172]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_VGG19_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_4_VGG19_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[104  15   5]
#  [ 38 285   2]
#  [  8   1 170]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_VGG19_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_VGG19_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 69  62  35]
#  [ 26 251  10]
#  [  1   0 189]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_VGG19_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_5_VGG19_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 92  42  32]
#  [ 36 246   5]
#  [  3   0 187]]

# %%
history={}
history['fold1']=np.load('history_last_fold1_wn.npy',allow_pickle=True).item()
history['fold2']=np.load('history_last_fold2_wn.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_VGG19_last.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_VGG19_last.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_VGG19_last.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_accuracy')
    plt.title('Training all layers')
    plt.show()
