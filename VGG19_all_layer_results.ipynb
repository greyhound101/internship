# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/VGG19_all_layer_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile 
  
with ZipFile('VGG19_all_fold_4.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# answers_all_fold_4_VGG19_last.npy              2020-05-27 07:34:20         5409
# predictions_all_fold_4_VGG19_last.npy          2020-05-27 07:34:20         5409
# final_accuracy_all_fold4_VGG19_last.npy        2020-05-27 07:34:20          397
# times_all_fold_4_VGG19_last.npy                2020-05-27 07:34:20          305
# history_all_fold_4_VGG19_last.npy              2020-05-27 07:34:20         7737
# predictions_all_best_fold_4_VGG19_last.npy     2020-05-27 07:34:20         5409
# best_accuracy_all_fold_4_VGG19_last.npy        2020-05-27 07:34:20          397
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile 
  
with ZipFile('VGG19_2_all.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# history_all_fold_2_VGG19_all.npy               2020-05-28 17:56:40         3640
# final_accuracy_all_fold2_VGG19_all.npy         2020-05-28 17:56:40          397
# answers_all_fold_2_VGG19_all.npy               2020-05-28 17:56:40         1058
# times_all_fold_2_VGG19_all.npy                 2020-05-28 17:56:40          305
# predictions_all_best_fold_2_VGG19_all.npy      2020-05-28 17:56:40         5817
# best_accuracy_all_fold_2_VGG19_all.npy         2020-05-28 17:56:40          397
# predictions_all_fold_2_VGG19_all.npy           2020-05-28 17:56:40         5817
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile 
  
with ZipFile('VGG19_fold_5_all.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# best_accuracy_all_fold_5_VGG19_all.npy         2020-05-27 14:50:10          397
# final_accuracy_all_fold5_VGG19_all.npy         2020-05-27 14:50:10          397
# predictions_all_best_fold_5_VGG19_all.npy      2020-05-27 14:50:10         5529
# times_all_fold_5_VGG19_all.npy                 2020-05-27 14:50:10          305
# predictions_all_fold_5_VGG19_all.npy           2020-05-27 14:50:10         5529
# answers_all_fold_5_VGG19_all.npy               2020-05-27 14:50:10         5529
# history_all_fold_5_VGG19_all.npy               2020-05-27 14:50:10         3640
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9101389110501135

# %%
import numpy as np
fnl_acc3=list(np.load('best_accuracy_all_fold_3_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('best_accuracy_all_fold_5_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('best_accuracy_all_fold_4_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('best_accuracy_all_fold_2_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('best_accuracy_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9201937843254303

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_VGG19_last.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_VGG19_all.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc4,fnl_acc5])
# Out:
# 11164.103969454765

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[105   7   0]
#  [  9 236   0]
#  [ 14   2 169]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[102  10   0]
#  [  2 242   1]
#  [  8   2 175]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_VGG19_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_VGG19_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[113  37  17]
#  [  8 319  11]
#  [  3   3 168]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_VGG19_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_2_VGG19_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[125  30  12]
#  [  7 321  10]
#  [  2   4 168]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_VGG19_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_VGG19_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[120  17   2]
#  [ 13 218   0]
#  [  7   4 191]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_VGG19_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_3_VGG19_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[121  16   2]
#  [ 12 219   0]
#  [  7   4 191]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_VGG19_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_VGG19_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 92  25   7]
#  [ 31 289   5]
#  [  6   1 172]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_VGG19_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_4_VGG19_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[104  15   5]
#  [ 38 285   2]
#  [  8   1 170]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_VGG19_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_VGG19_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[140   4  22]
#  [ 18 269   0]
#  [  3   4 183]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_VGG19_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_5_VGG19_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[135   5  26]
#  [ 16 271   0]
#  [  4   0 186]]

# %%
history={}
history['fold1']=np.load('history_last_fold1_wn.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_VGG19_all.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_VGG19_all.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_VGG19_last.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_VGG19_all.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title(fold)
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_accuracy')
    plt.title('Training all layers')
    plt.show()
