# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/VGG19_all_layer_without_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_VGG19_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_VGG19_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_VGG19_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_VGG19_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_VGG19_decay.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9487248178890393

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_VGG19_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_VGG19_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_VGG19_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_VGG19_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_VGG19_decay.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 10409.192837667466

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_VGG19_decay.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_VGG19_decay.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[108   4   0]
#  [  7 237   1]
#  [ 11   1 173]]

# %%
ans_1=np.load('answers_all_fold_2_VGG19_decay.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_VGG19_decay.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[148  18   1]
#  [ 10 323   5]
#  [  3   6 165]]

# %%
ans_1=np.load('answers_all_fold_3_VGG19_decay.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_VGG19_decay.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[133   4   2]
#  [ 13 218   0]
#  [  6   1 195]]

# %%
ans_1=np.load('answers_all_fold_4_VGG19_decay.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_VGG19_decay.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[116   5   3]
#  [  6 319   0]
#  [  4   0 175]]

# %%
ans_1=np.load('answers_all_fold_5_VGG19_decay.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_VGG19_decay.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[137   7  22]
#  [ 17 269   1]
#  [  1   0 189]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_VGG19_decay.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_VGG19_decay.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_VGG19_decay.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_VGG19_decay.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_VGG19_decay.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
