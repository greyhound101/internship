# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/squeeze_all_layer_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile 
  
with ZipFile('squeezenet_all_fold_3.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# predictions_all_fold_3_squeezenet_all.npy      2020-05-28 05:33:40         4961
# answers_all_fold_3_squeezenet_all.npy          2020-05-28 05:33:40         4961
# predictions_all_best_fold_3_squeezenet_all.npy 2020-05-28 05:33:40         4961
# final_accuracy_all_fold3_squeezenet_all.npy    2020-05-28 05:33:40          397
# history_all_fold_3_squeezenet_all.npy          2020-05-28 05:33:40         3640
# times_all_fold_3_squeezenet_all.npy            2020-05-28 05:33:40          305
# best_accuracy_all_fold_3_squeezenet_all.npy    2020-05-28 05:33:40          397
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_squeezenet_all.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9459057351282114

# %%
import numpy as np
fnl_acc3=list(np.load('best_accuracy_all_fold_3_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('best_accuracy_all_fold_5_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('best_accuracy_all_fold_4_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('best_accuracy_all_fold_2_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('best_accuracy_all_fold_1_squeezenet_all.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9509094013525798

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_squeezenet_all.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_squeezenet_all.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 5669.850569152832

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[104   7   1]
#  [  6 238   1]
#  [ 13   2 170]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_1_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[102   9   1]
#  [  2 242   1]
#  [  9   3 173]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[140  20   7]
#  [  9 320   9]
#  [  3   4 167]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_2_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[146  16   5]
#  [ 10 320   8]
#  [  4   4 166]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[132   4   3]
#  [ 10 221   0]
#  [  3   0 199]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_3_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[135   2   2]
#  [ 10 221   0]
#  [  2   1 199]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[107   8   9]
#  [  2 323   0]
#  [  5   1 173]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_4_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[111   6   7]
#  [  2 323   0]
#  [  8   0 171]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[137   4  25]
#  [  6 277   4]
#  [  1   1 188]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_squeezenet_all.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_5_squeezenet_all.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[137   4  25]
#  [  6 277   4]
#  [  1   1 188]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_squeezenet_all.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_squeezenet_all.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_squeezenet_all.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_squeezenet_all.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_squeezenet_all.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_accuracy')
    plt.title('Training all layers')
    plt.show()
