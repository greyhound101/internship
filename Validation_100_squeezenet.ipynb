# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/Validation_100_squeezenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile
with ZipFile('validation_100_fold_5.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# best_accuracy_all_fold_5_squeezenet_all_without_validation_100.npy 2020-06-02 10:06:36          397
# times_all_fold_5_squeezenet_all_without_validation_100.npy 2020-06-02 10:06:38          305
# predictions_all_best_fold_5_squeezenet_all_without_validation_100.npy 2020-06-02 10:06:38         5529
# final_accuracy_all_fold5_squeezenet_all_without_validation_100.npy 2020-06-02 10:06:36          397
# history_all_fold_5_squeezenet_all_without_validation_100.npy 2020-06-02 10:06:38         5881
# predictions_all_fold_5_squeezenet_all_without_validation_100.npy 2020-06-02 10:06:38         5529
# answers_all_fold_5_squeezenet_all_without_validation_100.npy 2020-06-02 10:06:38         5529
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9455703740596363

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_squeezenet_all_without_validation_100.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 10680.690624666215

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[101   7   4]
#  [  5 239   1]
#  [ 15   1 169]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[143  21   3]
#  [  5 325   8]
#  [  3   5 166]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[135   3   1]
#  [ 14 217   0]
#  [  2   1 199]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[109   8   7]
#  [  5 320   0]
#  [  6   0 173]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[132   8  26]
#  [  6 279   2]
#  [  0   1 189]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_squeezenet_all_without_validation_100.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
