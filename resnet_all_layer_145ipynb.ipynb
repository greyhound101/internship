# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/resnet_all_layer_145ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9567976043637859

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_Resnet_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 12190.51951508522

# %%
tot_pre=[]
tot_ans=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_Resnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_Resnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[111   1   0]
#  [  4 241   0]
#  [  9   6 170]]

# %%
ans_1=np.load('answers_all_fold_2_Resnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_Resnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[150  12   5]
#  [  7 328   3]
#  [  4   9 161]]

# %%
ans_1=np.load('answers_all_fold_3_Resnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_Resnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[134   4   1]
#  [ 16 214   1]
#  [  2   0 200]]

# %%
ans_1=np.load('answers_all_fold_4_Resnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_Resnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[115   5   4]
#  [  0 325   0]
#  [  2   2 175]]

# %%
ans_1=np.load('answers_all_fold_5_Resnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_Resnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[143   3  20]
#  [ 13 273   1]
#  [  0   0 190]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['meningioma', 'glioma','pituitary' ],yticklabels=['meningioma', 'glioma','pituitary' ])
plt.savefig('resnet.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
history={}
history['fold1']=np.load('history_all_fold_1_Resnet_decay_145.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_Resnet_decay_145.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_Resnet_decay_145.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_Resnet_decay_145.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_Resnet_decay_145.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
