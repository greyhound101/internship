# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/xception_all_layer_145.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_xception_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_xception_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_xception_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_xception_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_xception_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9546939364501588

# %%
fnl_acc3=list(np.load('times_all_fold_3_xception_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_xception_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_xception_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_xception_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_xception_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 34538.864204883575

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_xception_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_xception_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[112   0   0]
#  [ 11 234   0]
#  [  9   1 175]]

# %%
ans_1=np.load('answers_all_fold_2_xception_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_xception_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[152  15   0]
#  [ 12 326   0]
#  [  5  14 155]]

# %%
ans_1=np.load('answers_all_fold_3_xception_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_xception_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[135   3   1]
#  [ 16 215   0]
#  [  2   0 200]]

# %%
ans_1=np.load('answers_all_fold_4_xception_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_xception_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[115   5   4]
#  [  4 321   0]
#  [  4   2 173]]

# %%
ans_1=np.load('answers_all_fold_5_xception_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_xception_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[141   5  20]
#  [  6 280   1]
#  [  0   1 189]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_xception_decay_145.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_xception_decay_145.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_xception_decay_145.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_xception_decay_145.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_xception_decay_145.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
