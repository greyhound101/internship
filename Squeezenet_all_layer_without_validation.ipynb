# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/Squeezenet_all_layer_without_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile 
  
with ZipFile('squeezenet_fold_3.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# predictions_all_best_fold_3_squeezenet_decay.npy 2020-06-06 11:55:12          282
# best_accuracy_all_fold_3_squeezenet_decay.npy  2020-06-06 11:55:10          282
# answers_all_fold_3_squeezenet_decay.npy        2020-06-06 11:55:12         4961
# times_all_fold_3_squeezenet_decay.npy          2020-06-06 11:55:12          305
# history_all_fold_3_squeezenet_decay.npy        2020-06-06 11:55:12         2684
# predictions_all_fold_3_squeezenet_decay.npy    2020-06-06 11:55:12         4961
# final_accuracy_all_fold3_squeezenet_decay.npy  2020-06-06 11:55:12          397
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_squeezenet_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_squeezenet_deacy.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_squeezenet_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_squeezenet_deacy.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_squeezenet_deacy.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9354802827544036

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_squeezenet_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_squeezenet_deacy.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_squeezenet_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_squeezenet_deacy.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_squeezenet_deacy.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 5128.458692598343

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_squeezenet_deacy.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_squeezenet_deacy.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[105   5   2]
#  [  2 243   0]
#  [ 14   0 171]]

# %%
ans_1=np.load('answers_all_fold_2_squeezenet_deacy.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_squeezenet_deacy.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[137  24   6]
#  [ 11 321   6]
#  [  5   3 166]]

# %%
ans_1=np.load('answers_all_fold_3_squeezenet_decay.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_squeezenet_decay.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[130   5   4]
#  [ 22 209   0]
#  [  4   0 198]]

# %%
ans_1=np.load('answers_all_fold_4_squeezenet_decay.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_squeezenet_decay.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[113   8   3]
#  [ 13 309   3]
#  [  2   1 176]]

# %%
ans_1=np.load('answers_all_fold_5_squeezenet_deacy.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_squeezenet_deacy.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[121  14  31]
#  [  9 275   3]
#  [  0   1 189]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_squeezenet_deacy.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_squeezenet_deacy.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_squeezenet_decay.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_squeezenet_decay.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_squeezenet_deacy.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
