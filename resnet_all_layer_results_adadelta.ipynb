# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/resnet_all_layer_results_adadelta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.93479330459892

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_Resnet_adadelta.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 12296.14083199501

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_Resnet_adadelta.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_Resnet_adadelta.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[109   2   1]
#  [  9 236   0]
#  [  6   1 178]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_Resnet_adadelta.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_Resnet_adadelta.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[141  14  12]
#  [ 18 313   7]
#  [  4   6 164]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_Resnet_adadelta.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_Resnet_adadelta.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[128   9   2]
#  [ 25 206   0]
#  [  1   0 201]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_4_Resnet_adadelta.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_Resnet_adadelta.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[114   6   4]
#  [ 14 311   0]
#  [  7   0 172]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_5_Resnet_adadelta.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_Resnet_adadelta.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[129   6  31]
#  [ 18 268   1]
#  [  0   0 190]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_Resnet_adadelta.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_Resnet_adadelta.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_Resnet_adadelta.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_Resnet_adadelta.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_Resnet_adadelta.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
