# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/VGG16_all_layer_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile 
  
with ZipFile('VGG_16_fold_5_all.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# final_accuracy_all_fold5_wn.npy                2020-05-26 12:27:56          397
# predictions_all_best_fold5_wn.npy              2020-05-26 12:28:08         5529
# history_all_fold5_wn.npy                       2020-05-26 12:27:58         3640
# best_accuracy_all_fold5_wn.npy                 2020-05-26 12:27:56          397
# predictions_all_fold5_wn.npy                   2020-05-26 12:28:06         5529
# times_all_fold5_wn.npy                         2020-05-26 12:28:08          305
# answers_all_fold5_wn.npy                       2020-05-26 12:28:06         5529
# Extracting all the files now...
# Done!

# %%
from zipfile import ZipFile 
  
with ZipFile('VGG16_4_all.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# final_accuracy_all_fold1.npy                   2020-05-26 23:50:04          397
# best_accuracy_all_fold1.npy                    2020-05-26 23:50:04          397
# predictions_all_best_fold1.npy                 2020-05-26 23:50:04         5409
# times_all_fold1.npy                            2020-05-26 23:50:04          305
# answers_last_fold1.npy                         2020-05-26 23:50:04         5409
# history_last_fold1.npy                         2020-05-26 23:50:04         3640
# predictions_last_fold1.npy                     2020-05-26 23:50:04         5409
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold1.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9109074628097635

# %%
import numpy as np
fnl_acc3=list(np.load('best_accuracy_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('best_accuracy_all_fold5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('best_accuracy_all_fold1.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('best_accuracy_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('best_accuracy_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9416907262645442

# %%
import numpy as np
fnl_acc3=list(np.load('times_last_fold3.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold1.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_last_fold2_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_last_fold1_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 11227.289118242265

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 89  23   0]
#  [ 14 231   0]
#  [  9   5 171]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[101  11   0]
#  [ 10 235   0]
#  [ 11   2 172]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[139  22   6]
#  [ 34 299   5]
#  [  2   8 164]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold2_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold2_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[150  15   2]
#  [ 12 317   9]
#  [  4   7 163]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold3.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold3.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[135   3   1]
#  [ 16 215   0]
#  [  1   0 201]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold3.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold3.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[130   8   1]
#  [  4 227   0]
#  [  0   3 199]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 89  23   0]
#  [ 14 231   0]
#  [  9   5 171]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold1_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[101  11   0]
#  [ 10 235   0]
#  [ 11   2 172]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold5_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold5_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[135   3  28]
#  [ 25 262   0]
#  [  2   1 187]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold5_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold5_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[137   6  23]
#  [ 17 268   2]
#  [  2   1 187]]

# %%
history={}
history['fold1']=np.load('history_last_fold1_wn.npy',allow_pickle=True).item()
history['fold2']=np.load('history_last_fold2_wn.npy',allow_pickle=True).item()
history['fold3']=np.load('history_last_fold3.npy',allow_pickle=True).item()
history['fold4']=np.load('history_last_fold1.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold5_wn.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_accuracy')
    plt.title('Training all layers')
    plt.show()
