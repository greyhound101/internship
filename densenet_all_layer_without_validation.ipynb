# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/densenet_all_layer_without_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile 
  
with ZipFile('densenet_fold_3.zip', 'r') as zip: 
    # printing all the contents of the zip file 
    zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# File Name                                             Modified             Size
# predictions_all_best_fold_3_densenet_decay.npy 2020-06-06 09:12:34          282
# best_accuracy_all_fold_3_densenet_decay.npy    2020-06-06 09:12:34          282
# times_all_fold_3_densenet_decay.npy            2020-06-06 09:12:34          305
# predictions_all_fold_3_densenet_decay.npy      2020-06-06 09:12:34         4961
# history_all_fold_3_densenet_decay.npy          2020-06-06 09:12:34         2684
# answers_all_fold_3_densenet_decay.npy          2020-06-06 09:12:34         4961
# final_accuracy_all_fold3_densenet_decay.npy    2020-06-06 09:12:34          397
# Extracting all the files now...
# Done!

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_densenet_decay.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_last_fold5.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_last_fold2.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_last_fold1.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9409363837762801

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[108   4   0]
#  [  5 238   2]
#  [  7   4 174]]

# %%
ans_1=np.load('answers_last_fold2.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold2.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[149  13   5]
#  [  5 327   6]
#  [  4   7 163]]

# %%
ans_1=np.load('answers_all_fold_3_densenet_decay.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_densenet_decay.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[126   5   8]
#  [ 25 206   0]
#  [  5   0 197]]

# %%
ans_1=np.load('answers_last_fold4.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold4.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[114   3   7]
#  [  9 316   0]
#  [  5   0 174]]

# %%
ans_1=np.load('answers_last_fold5.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold5.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[140   2  24]
#  [ 26 261   0]
#  [  0   1 189]]

# %%
history={}
history['fold1']=np.load('history_last_fold1.npy',allow_pickle=True).item()
history['fold2']=np.load('history_last_fold2.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_densenet_decay.npy',allow_pickle=True).item()
history['fold4']=np.load('history_last_fold4.npy',allow_pickle=True).item()
history['fold5']=np.load('history_last_fold5.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
