# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/VGG19_all_results_145.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9172386463641893

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_VGG19_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 11143.465442037583

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_VGG19_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_VGG19_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[102  10   0]
#  [  6 238   1]
#  [ 17   2 166]]

# %%
ans_1=np.load('answers_all_fold_2_VGG19_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_VGG19_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[134  23  10]
#  [ 13 319   6]
#  [  4   9 161]]

# %%
ans_1=np.load('answers_all_fold_3_VGG19_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_VGG19_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[128  11   0]
#  [ 22 209   0]
#  [  3   2 197]]

# %%
ans_1=np.load('answers_all_fold_4_VGG19_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_VGG19_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[109   6   9]
#  [ 24 299   2]
#  [  5   0 174]]

# %%
ans_1=np.load('answers_all_fold_5_VGG19_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_VGG19_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[124  18  24]
#  [ 24 263   0]
#  [  4   2 184]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_VGG19_decay_145.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_VGG19_decay_145.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_VGG19_decay_145.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_VGG19_decay_145.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_VGG19_decay_145.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
