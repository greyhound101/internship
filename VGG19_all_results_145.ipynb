# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/VGG19_all_results_145.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold3_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_all_fold5_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_all_fold4_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_all_fold1_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.8945108040121312

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_all_fold_5_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_all_fold_4_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_all_fold_1_alexnet_decay_145.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 5619.727446699142

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_1_alexnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_1_alexnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 89  23   0]
#  [ 14 228   3]
#  [  7   6 172]]

# %%
ans_1=np.load('answers_all_fold_2_alexnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_alexnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[133  20  14]
#  [ 18 312   8]
#  [  5   1 168]]

# %%
ans_1=np.load('answers_all_fold_3_alexnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_alexnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[121  15   3]
#  [ 31 198   2]
#  [  7   4 191]]

# %%
ans_1=np.load('answers_all_fold_4_alexnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_4_alexnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[108   9   7]
#  [ 20 302   3]
#  [  6   0 173]]

# %%
ans_1=np.load('answers_all_fold_5_alexnet_decay_145.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_5_alexnet_decay_145.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[ 99  38  29]
#  [ 26 261   0]
#  [  2   3 185]]

# %%
history={}
history['fold1']=np.load('history_all_fold_1_alexnet_decay_145.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_alexnet_decay_145.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_alexnet_decay_145.npy',allow_pickle=True).item()
history['fold4']=np.load('history_all_fold_4_alexnet_decay_145.npy',allow_pickle=True).item()
history['fold5']=np.load('history_all_fold_5_alexnet_decay_145.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
