# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/internship/blob/master/resnet_last_layer_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc3=list(np.load('final_accuracy_all_fold_3_Resnet_last.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('final_accuracy_last_fold5.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('final_accuracy_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('final_accuracy_all_fold2_Resnet_last.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('final_accuracy_last_fold1.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.27931397250987827

# %%
import numpy as np
fnl_acc3=list(np.load('best_accuracy_all_fold_3_Resnet_last.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('best_accuracy_last_fold5.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('best_accuracy_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('best_accuracy_all_fold_2_Resnet_last.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('best_accuracy_last_fold1.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.33776016549215376

# %%
import numpy as np
fnl_acc3=list(np.load('times_all_fold_3_Resnet_last.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('times_last_fold5.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('times_last_fold4.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('times_all_fold_2_Resnet_last.npy',allow_pickle=True).item().values())[0]
fnl_acc1=list(np.load('times_last_fold1.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 7531.176145648957

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold1.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[112   0   0]
#  [245   0   0]
#  [185   0   0]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold1.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold1.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[112   0   0]
#  [245   0   0]
#  [185   0   0]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_Resnet_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_2_Resnet_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0   0 167]
#  [  0   0 338]
#  [  0   0 174]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_2_Resnet_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_2_Resnet_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0 167   0]
#  [  0 338   0]
#  [  0 174   0]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_Resnet_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_fold_3_Resnet_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0   0 139]
#  [  0   0 231]
#  [  0   0 202]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_all_fold_3_Resnet_last.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_all_best_fold_3_Resnet_last.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0 139   0]
#  [  0 231   0]
#  [  0 202   0]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold4.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold4.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0   0 124]
#  [  0   0 325]
#  [  0   0 179]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold4.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold4.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0   0 124]
#  [  0   0 325]
#  [  0   0 179]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold5.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_fold5.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  0   0 166]
#  [  0   0 287]
#  [  0   0 190]]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('answers_last_fold5.npy',allow_pickle=True).item()
fold_1_pre=np.load('predictions_last_best_fold5.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[  1   0 165]
#  [  0   0 287]
#  [  1   0 189]]

# %%
history={}
history['fold1']=np.load('history_last_fold1.npy',allow_pickle=True).item()
history['fold2']=np.load('history_all_fold_2_Resnet_last.npy',allow_pickle=True).item()
history['fold3']=np.load('history_all_fold_3_Resnet_last.npy',allow_pickle=True).item()
history['fold4']=np.load('history_last_fold4.npy',allow_pickle=True).item()
history['fold5']=np.load('history_last_fold5.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_loss')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['val_accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('val_accuracy')
    plt.title('Training all layers')
    plt.show()
